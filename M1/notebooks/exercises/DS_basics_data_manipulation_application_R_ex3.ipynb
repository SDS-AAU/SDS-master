# %% [markdown]
# <a href="https://colab.research.google.com/github/SDS-AAU/SDS-master/blob/master/M1/notebooks/exercises/DS_basics_data_manipulation_application_R_ex3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Importing packages
library(tidyverse) # metapackage with lots of helpful functions
library(magrittr)

# %% [markdown]
# So, lets load the UN votes data.

# %%
votes <- url("https://github.com/SDS-AAU/M1-2019/raw/master/data/UN_votes.rds") %>% readRDS()
head(votes)

# %% [markdown]
# And also the descriptions:

# %%
descriptions <- url("https://github.com/SDS-AAU/M1-2019/blob/master/data/UN_votes_descriptions.rds") %>% readRDS()
head(descriptions)

# %% [markdown]
# Ok, we have the data together. Lets try to first:
#
# 1. Clean the votes data a bit. You remember how...

# %% [markdown]
# 2. Explore the dataset a bit. What do you find interesting?

# %% [markdown]
# 3. Clean also the description data. You know how

# %% [markdown]
# 4. Also, lets explore it a bit. Be creative

# %% [markdown]
# 5. Join the two datasets

# %% [markdown]
# 6. Also, get some worldbank data, and see if it would explain something

# %%
library(wbstats)
str(wb_cachelist, max.level = 1)
wbsearch(pattern = "XXXXX")
